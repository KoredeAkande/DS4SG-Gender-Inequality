# %% [markdown]
# # Gender Detection using names
#
# **`Goal`:** Determine the gender of the freelancer using the first names extracted and cleaned in previous steps/notebooks

# %% [markdown]
# ### 1. Import packages

# %%
#General packages for dataframe and data manipulation
import pandas as pd
import numpy as np

#Gender detection packages
from genderize import Genderize
import gender_guesser.detector as gender

# %% [markdown]
# ### 2. Load the data

# %%
df = pd.read_csv('../data/interim/cleaned-merge.csv')
df.head()
# Out:
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3524: DtypeWarning: Columns (597,598) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   search_query     name                                 profile_link  \
# 0     designer    Milen  https://www.freelancer.com/u/MsCaddServices
# 1     designer   Jeremy         https://www.freelancer.com/u/Conescu
# 2     designer  Nichole       https://www.freelancer.com/u/NicholeMW
# 3     designer   Robert     https://www.freelancer.com/u/rhoenig1277
# 4     designer     Shea      https://www.freelancer.com/u/blaqsupply
#
#        location  hourly_rate  pay_grade  avg_rating  num_reviews  \
# 0       Edmonds         45.0        0.0         0.0            0
# 1        Orinda         90.0        0.0         0.0            0
# 2         Holly         25.0        4.0         5.0            2
# 3        Beloit         75.0        0.0         0.0            0
# 4  Cockeysville         25.0        0.0         0.0            0
#
#    num_recommendations  pct_jobs_completed  ...  \
# 0                    0                 NaN  ...
# 1                    0                 NaN  ...
# 2                    0               100.0  ...
# 3                    0                 NaN  ...
# 4                    0                 NaN  ...
#
#    pct_certifications_requirements_engineering_1  skill_furniture_removalist  \
# 0                                            NaN                         NaN
# 1                                            NaN                         NaN
# 2                                            NaN                         NaN
# 3                                            NaN                         NaN
# 4                                            NaN                         NaN
#
#    skill_workday_security  skill_oracle_ebs_tech_integration  \
# 0                     NaN                                NaN
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                NaN
#
#    pct_certifications_google_webmaster_central_1  skill_modx  skill_cubecart  \
# 0                                            NaN         NaN             NaN
# 1                                            NaN         NaN             NaN
# 2                                            NaN         NaN             NaN
# 3                                            NaN         NaN             NaN
# 4                                            NaN         NaN             NaN
#
#    skill_phaser  skill_drilling_engineering  skill_casperjs
# 0           NaN                         NaN             NaN
# 1           NaN                         NaN             NaN
# 2           NaN                         NaN             NaN
# 3           NaN                         NaN             NaN
# 4           NaN                         NaN             NaN
#
# [5 rows x 2265 columns]

# %% [markdown]
# ### 3. Gender Detection Pipeline

# %%
#Initialize the main detector
gender_detector = gender.Detector()

# %%
def determine_gender(name,prob_threshold = 0.8,count_threshold=50):

    """
    MAIN FUNCTION

    Function to determine gender for an inputted first name 
    Prediction by second option detector is adjusted based on a probability and frequency threshold

    Inputs:
        - name (str): The first name to predict gender based on
        - prob_threshold (float): The probability of the classification being 
                                  correct (proxy for confidence). Default: 0.8
        - count_threshold (float): The number of samples the classification is based on. 
                                   Default: 50
    
    Output:
        - pred (str): Gender prediction


    """
    
    #Try to detect gender for the inputted name using first model
    pred = gender_detector.get_gender(name)

    #If the model predicts male or female, return the prediction
    if pred in ('male','female'):
        return pred
    
    #If it predicts mostly male or mostly female, go with prediction (male or female)
    elif 'mostly' in pred:
        return pred.replace('mostly_','')

    #If the model cannot determine the gender ('unknown') or is unsure ('andy')
    else:

        #Pass prediction task to the other model (Only 1000 free requests daily)
        try:
            alt_pred = Genderize().get1(name)

            #If the prediction stats pass the set threshold
            if alt_pred['probability'] >= prob_threshold and alt_pred['count'] >= count_threshold:
                return alt_pred['gender']
            
            #If not, note the model's confidence level and leave for human reannotation
            else:
                return 'low_confidence'
        
        #If an exception occurs (mostly API request limit met), report error
        except:
            return 'error'

# %%
def alt_determine_gender(name,prob_threshold = 0.8,count_threshold=50):

    """

    ALTERNATIVE FUNCTION – SEE USE CASE BELOW
    
    This function only leverages the genderize.io api unlike the main determine_gender() function
    Prediction is adjusted based on a probability and frequency threshold.

    USE CASE FOR THIS FUNCTION
        - If the rate limit was reached when using the genderize.io api
          incorporated within main determine_gender() function. This function might 
          the run the following day when the requests quota is restored
    
    Inputs:
        - name (str): The first name to predict gender based on
        - prob_threshold (float): The probability of the classification being 
                                  correct (proxy for confidence). Default: 0.8
        - count_threshold (float): The number of samples the classification is based on. 
                                   Default: 50
    
    Output:
        - pred (str): Gender prediction


    """

    try:
        alt_pred = Genderize().get1(name)

        #If the prediction stats pass the set threshold
        if alt_pred['probability'] >= prob_threshold and alt_pred['count'] >= count_threshold:
            return alt_pred['gender']
        
        #If not, note the model's confidence level and leave for human reannotation
        else:
            return 'low_confidence'
    
    #If an exception occurs (most likely request limit exceeded)
    except:
        return 'error'

# %% [markdown]
# ### 4. Predict gender for the dataset

# %%
#Predict the gender
gender_preds = df.name.apply(determine_gender)
df['gender'] = gender_preds

#Reorganize dataframe so gender is next to name
df.insert(int(np.where(df.columns == 'name')[0][0]+1),'gender',df.pop('gender'))

# %%
df
# Out:
#             search_query      name    gender  \
# 0               designer     Milen      male
# 1               designer    Jeremy      male
# 2               designer   Nichole    female
# 3               designer    Robert      male
# 4               designer      Shea  low_conf
# ...                  ...       ...       ...
# 10089  software engineer    Jackie     error
# 10090  software engineer      Alex      male
# 10091  software engineer  Jonathan      male
# 10092  software engineer       Dee    female
# 10093  software engineer       Sam      male
#
#                                       profile_link        location  \
# 0      https://www.freelancer.com/u/MsCaddServices         Edmonds
# 1             https://www.freelancer.com/u/Conescu          Orinda
# 2           https://www.freelancer.com/u/NicholeMW           Holly
# 3         https://www.freelancer.com/u/rhoenig1277          Beloit
# 4          https://www.freelancer.com/u/blaqsupply    Cockeysville
# ...                                            ...             ...
# 10089      https://www.freelancer.com/u/jackielinn           Tyler
# 10090         https://www.freelancer.com/u/aresnik          Hamden
# 10091      https://www.freelancer.com/u/tcoffin014  Denham Springs
# 10092  https://www.freelancer.com/u/IntelligentDee       Arlington
# 10093      https://www.freelancer.com/u/samraola30         Addison
#
#        hourly_rate  pay_grade  avg_rating  num_reviews  num_recommendations  \
# 0             45.0        0.0         0.0            0                    0
# 1             90.0        0.0         0.0            0                    0
# 2             25.0        4.0         5.0            2                    0
# 3             75.0        0.0         0.0            0                    0
# 4             25.0        0.0         0.0            0                    0
# ...            ...        ...         ...          ...                  ...
# 10089         30.0        0.0         0.0            0                    0
# 10090         15.0        0.4         5.0            1                    0
# 10091        150.0        0.0         0.0            0                    0
# 10092         25.0        0.0         0.0            0                    3
# 10093         50.0        0.0         0.0            0                    0
#
#        ...  pct_certifications_requirements_engineering_1  \
# 0      ...                                            NaN
# 1      ...                                            NaN
# 2      ...                                            NaN
# 3      ...                                            NaN
# 4      ...                                            NaN
# ...    ...                                            ...
# 10089  ...                                            NaN
# 10090  ...                                            NaN
# 10091  ...                                            NaN
# 10092  ...                                            NaN
# 10093  ...                                            NaN
#
#        skill_furniture_removalist  skill_workday_security  \
# 0                             NaN                     NaN
# 1                             NaN                     NaN
# 2                             NaN                     NaN
# 3                             NaN                     NaN
# 4                             NaN                     NaN
# ...                           ...                     ...
# 10089                         NaN                     NaN
# 10090                         NaN                     NaN
# 10091                         NaN                     NaN
# 10092                         NaN                     NaN
# 10093                         NaN                     NaN
#
#        skill_oracle_ebs_tech_integration  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 10089                                NaN
# 10090                                NaN
# 10091                                NaN
# 10092                                NaN
# 10093                                NaN
#
#        pct_certifications_google_webmaster_central_1  skill_modx  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2                                                NaN         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN
# ...                                              ...         ...
# 10089                                            NaN         NaN
# 10090                                            NaN         NaN
# 10091                                            NaN         NaN
# 10092                                            NaN         NaN
# 10093                                            NaN         NaN
#
#        skill_cubecart  skill_phaser  skill_drilling_engineering  \
# 0                 NaN           NaN                         NaN
# 1                 NaN           NaN                         NaN
# 2                 NaN           NaN                         NaN
# 3                 NaN           NaN                         NaN
# 4                 NaN           NaN                         NaN
# ...               ...           ...                         ...
# 10089             NaN           NaN                         NaN
# 10090             NaN           NaN                         NaN
# 10091             NaN           NaN                         NaN
# 10092             NaN           NaN                         NaN
# 10093             NaN           NaN                         NaN
#
#        skill_casperjs
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 10089             NaN
# 10090             NaN
# 10091             NaN
# 10092             NaN
# 10093             NaN
#
# [10094 rows x 2266 columns]

# %% [markdown]
# ### 5. Get cases where model is not confident or where error occured

# %%
df.query("(gender=='error') or (gender == 'low_conf')")
# Out:
#             search_query          name gender  \
# 4186            designer      Shang-Te  error
# 4197            designer  LKrketing,c.  error
# 4203            designer             C  error
# 4204            designer       Dariell  error
# 4208            designer        Lamyaa  error
# ...                  ...           ...    ...
# 10074  software engineer        Jousef  error
# 10082  software engineer       Jaimean  error
# 10085  software engineer      Prapulla  error
# 10088  software engineer         Tunde  error
# 10089  software engineer        Jackie  error
#
#                                      profile_link       location  hourly_rate  \
# 4186     https://www.freelancer.com/u/tedchen0313  San Francisco         20.0
# 4197        https://www.freelancer.com/u/lkonomos   Blue Springs         25.0
# 4203         https://www.freelancer.com/u/cbrinks        Dunedin         10.0
# 4204   https://www.freelancer.com/u/dariellellis7        Memphis         20.0
# 4208    https://www.freelancer.com/u/lamyaahassan     Sugar Land         75.0
# ...                                           ...            ...          ...
# 10074    https://www.freelancer.com/u/akifcamizci       Woodbury         35.0
# 10082        https://www.freelancer.com/u/jagcruz       Marianao          8.0
# 10085           https://www.freelancer.com/u/abpp       Elkridge         35.0
# 10088         https://www.freelancer.com/u/tuns21       Kennesaw         60.0
# 10089     https://www.freelancer.com/u/jackielinn          Tyler         30.0
#
#        pay_grade  avg_rating  num_reviews  num_recommendations  ...  \
# 4186         5.0         5.0            9                    0  ...
# 4197         1.4         4.6            1                    0  ...
# 4203         0.0         0.0            0                    3  ...
# 4204         0.0         0.0            0                    0  ...
# 4208         1.1         5.0            1                    0  ...
# ...          ...         ...          ...                  ...  ...
# 10074        0.0         0.0            0                    0  ...
# 10082        0.0         0.0            0                    0  ...
# 10085        0.0         0.0            0                    0  ...
# 10088        0.0         0.0            0                    0  ...
# 10089        0.0         0.0            0                    0  ...
#
#        pct_certifications_requirements_engineering_1  \
# 4186                                             NaN
# 4197                                             NaN
# 4203                                             NaN
# 4204                                             NaN
# 4208                                             NaN
# ...                                              ...
# 10074                                            NaN
# 10082                                            NaN
# 10085                                            NaN
# 10088                                            NaN
# 10089                                            NaN
#
#        skill_furniture_removalist  skill_workday_security  \
# 4186                          NaN                     NaN
# 4197                          NaN                     NaN
# 4203                          NaN                     NaN
# 4204                          NaN                     NaN
# 4208                          NaN                     NaN
# ...                           ...                     ...
# 10074                         NaN                     NaN
# 10082                         NaN                     NaN
# 10085                         NaN                     NaN
# 10088                         NaN                     NaN
# 10089                         NaN                     NaN
#
#        skill_oracle_ebs_tech_integration  \
# 4186                                 NaN
# 4197                                 NaN
# 4203                                 NaN
# 4204                                 NaN
# 4208                                 NaN
# ...                                  ...
# 10074                                NaN
# 10082                                NaN
# 10085                                NaN
# 10088                                NaN
# 10089                                NaN
#
#        pct_certifications_google_webmaster_central_1  skill_modx  \
# 4186                                             NaN         NaN
# 4197                                             NaN         NaN
# 4203                                             NaN         NaN
# 4204                                             NaN         NaN
# 4208                                             NaN         NaN
# ...                                              ...         ...
# 10074                                            NaN         NaN
# 10082                                            NaN         NaN
# 10085                                            NaN         NaN
# 10088                                            NaN         NaN
# 10089                                            NaN         NaN
#
#        skill_cubecart  skill_phaser  skill_drilling_engineering  \
# 4186              NaN           NaN                         NaN
# 4197              NaN           NaN                         NaN
# 4203              NaN           NaN                         NaN
# 4204              NaN           NaN                         NaN
# 4208              NaN           NaN                         NaN
# ...               ...           ...                         ...
# 10074             NaN           NaN                         NaN
# 10082             NaN           NaN                         NaN
# 10085             NaN           NaN                         NaN
# 10088             NaN           NaN                         NaN
# 10089             NaN           NaN                         NaN
#
#        skill_casperjs
# 4186              NaN
# 4197              NaN
# 4203              NaN
# 4204              NaN
# 4208              NaN
# ...               ...
# 10074             NaN
# 10082             NaN
# 10085             NaN
# 10088             NaN
# 10089             NaN
#
# [1491 rows x 2266 columns]

# %%
df.gender.value_counts()
# Out:
# male        5404
# female      2479
# error       1491
# low_conf     720
# Name: gender, dtype: int64

# %% [markdown]
# ### 6. Re-predict gender for 'error' values when request quota replenished

# %%
#Load the data from previous checkpoint
gender_df = pd.read_csv('../data/gender-annotated/cleaned-gender-annotated-v2.csv',low_memory=False)

# %%
#Run gender identification pipeline on the data
gender_df.loc[gender_df.gender == 'error','gender'] = gender_df.loc[gender_df.gender == 'error','name'].apply(alt_determine_gender)

# %%
#Error in coding. My bad! Replace low_conf with low_confidence
gender_df.loc[gender_df.gender == 'low_conf','gender'] = 'low_confidence'

# %%
gender_df.gender.value_counts()
# Out:
# male              5750
# female            2569
# low_confidence    1775
# Name: gender, dtype: int64

# %% [markdown]
# ### 7. Export CSV for future runs and human reannotation

# %%
#df.to_csv('../data/gender-annotated/cleaned-gender-annotated-v1.csv',index=False)
gender_df.to_csv('../data/gender-annotated/cleaned-gender-annotated-v2.csv',index=False)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=acc27b92-84be-4130-8026-204943f38189' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
