# %% [markdown]
# # Data Cleaner
#
# **`Goal:`** Clean the data extracted from freelancer.com in preparation for gender identification, EDA, modeling and matching

# %% [markdown]
# ### 1. Import packages

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
from glob import glob

# %% [markdown]
# ### 2. Load the data

# %%
file_paths = [file for file in glob("../data/raw/*.csv") if '_raw' not in file]
file_paths
# Out:
# ['../data/raw/copywriter.csv',
#  '../data/raw/software_engineer.csv',
#  '../data/raw/designer.csv',
#  '../data/raw/accountant.csv']

# %% [markdown]
# ### 3. Exploring the data to inform cleaning

# %%
df = pd.read_csv(file_paths[0])
df.head()
# Out:
#   search_query         name                                   profile_link  \
# 0   copywriter     Marty P.            https://www.freelancer.com/u/mpekar
# 1   copywriter       Cat A.           https://www.freelancer.com/u/Cadduci
# 2   copywriter  Jonathan G.              https://www.freelancer.com/u/JG24
# 3   copywriter   Melanie B.     https://www.freelancer.com/u/Melwritesindy
# 4   copywriter  Brittney G.  https://www.freelancer.com/u/satisfiedsoulcre
#
#                                              tagline  \
# 0            Very experienced advertising copywriter
# 1     Marketing, Business and Administrative Support
# 2  Copy Editor, Copywriter, and Marketing Specialist
# 3                   Creative Writer, Copywriter, Mom
# 4                 Copywriter & Brand Content Creator
#
#                                     user_description  \
# 0  I'm a semi-retired advertising copywriter with...
# 1  My name is Cat and I am a Marketing and Commun...
# 2  Wordsmith, editing extraordinaire, and dedicat...
# 3  I studied Creative Writing and English Educati...
# 4  I am your secret weapon to bettering your bran...
#
#                       location          join_date hourly_rate  pay_grade  \
# 0     Greenwich, United States      July 18, 2011         $20        3.6
# 1       Hatboro, United States    August 28, 2021         $15        0.0
# 2       Warwick, United States   January 26, 2016         $20        0.0
# 3  Indianapolis, United States  December 14, 2021         $50        0.0
# 4       Memphis, United States     April 12, 2021         $25        0.0
#
#    avg_rating  ...  skill_electric_repair  skill_handyman  \
# 0         5.0  ...                    NaN             NaN
# 1         0.0  ...                    NaN             NaN
# 2         0.0  ...                    NaN             NaN
# 3         0.0  ...                    NaN             NaN
# 4         0.0  ...                    NaN             NaN
#
#    skill_order_processing  skill_analytics  skill_comics  \
# 0                     NaN              NaN           NaN
# 1                     NaN              NaN           NaN
# 2                     NaN              NaN           NaN
# 3                     NaN              NaN           NaN
# 4                     NaN              NaN           NaN
#
#    skill_public_speaking skill_political_science  skill_activecampaign  \
# 0                    NaN                     NaN                   NaN
# 1                    NaN                     NaN                   NaN
# 2                    NaN                     NaN                   NaN
# 3                    NaN                     NaN                   NaN
# 4                    NaN                     NaN                   NaN
#
#    skill_automotive_engineering  skill_influencer_marketing
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
# [5 rows x 735 columns]

# %% [markdown]
# #### a. Observing non-skill columns to inform data cleaning

# %%
df.loc[:,[col for col in df.columns if 'skill' not in col]]
# Out:
#     search_query           name  \
# 0     copywriter       Marty P.
# 1     copywriter         Cat A.
# 2     copywriter    Jonathan G.
# 3     copywriter     Melanie B.
# 4     copywriter    Brittney G.
# ..           ...            ...
# 658   copywriter    Theodore G.
# 659   copywriter      Luminacht
# 660   copywriter        Emma D.
# 661   copywriter    Jonathan C.
# 662   copywriter  Nicci Anna K.
#
#                                       profile_link  \
# 0              https://www.freelancer.com/u/mpekar
# 1             https://www.freelancer.com/u/Cadduci
# 2                https://www.freelancer.com/u/JG24
# 3       https://www.freelancer.com/u/Melwritesindy
# 4    https://www.freelancer.com/u/satisfiedsoulcre
# ..                                             ...
# 658       https://www.freelancer.com/u/greenequail
# 659         https://www.freelancer.com/u/Luminacht
# 660    https://www.freelancer.com/u/emmadenning132
# 661        https://www.freelancer.com/u/tcoffin014
# 662    https://www.freelancer.com/u/NicciAKilcoyne
#
#                                                tagline  \
# 0              Very experienced advertising copywriter
# 1       Marketing, Business and Administrative Support
# 2    Copy Editor, Copywriter, and Marketing Specialist
# 3                     Creative Writer, Copywriter, Mom
# 4                   Copywriter & Brand Content Creator
# ..                                                 ...
# 658                             Writer and Illustrator
# 659                                Professional Editor
# 660                              Copywriter and Editor
# 661    Email Marketing Copywriter, Mechanical Engineer
# 662     Copywriter. Blogger. Freelance Writer. Author.
#
#                                       user_description  \
# 0    I'm a semi-retired advertising copywriter with...
# 1    My name is Cat and I am a Marketing and Commun...
# 2    Wordsmith, editing extraordinaire, and dedicat...
# 3    I studied Creative Writing and English Educati...
# 4    I am your secret weapon to bettering your bran...
# ..                                                 ...
# 658  I am a great writer and drawer of great pictur...
# 659  I am a skilled and experienced Editor, Proofre...
# 660  I have been Copywriting as a side hustle for a...
# 661  Jack of all trades. Mechanical engineer, car a...
# 662  I help businesses reach their target audience ...
#
#                           location          join_date hourly_rate  pay_grade  \
# 0         Greenwich, United States      July 18, 2011         $20        3.6
# 1           Hatboro, United States    August 28, 2021         $15        0.0
# 2           Warwick, United States   January 26, 2016         $20        0.0
# 3      Indianapolis, United States  December 14, 2021         $50        0.0
# 4           Memphis, United States     April 12, 2021         $25        0.0
# ..                             ...                ...         ...        ...
# 658      Scottsdale, United States     August 6, 2020         $20        4.7
# 659       Kissimmee, United States    October 5, 2020         $12        0.0
# 660       Bryn Mawr, United States  November 10, 2020         $11        0.0
# 661  Denham Springs, United States   January 10, 2022        $150        0.0
# 662      Wilmington, United States  November 11, 2018         $60        1.3
#
#      avg_rating  ...  certifications_spanish_1  certifications_german_1  \
# 0           5.0  ...                       NaN                      NaN
# 1           0.0  ...                       NaN                      NaN
# 2           0.0  ...                       NaN                      NaN
# 3           0.0  ...                       NaN                      NaN
# 4           0.0  ...                       NaN                      NaN
# ..          ...  ...                       ...                      ...
# 658         4.9  ...                       NaN                      NaN
# 659         0.0  ...                       NaN                      NaN
# 660         0.0  ...                       NaN                      NaN
# 661         0.0  ...                       NaN                      NaN
# 662         5.0  ...                       NaN                      NaN
#
#      certifications_joomla!_1  certifications_drupal_1  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# ..                        ...                      ...
# 658                       NaN                      NaN
# 659                       NaN                      NaN
# 660                       NaN                      NaN
# 661                       NaN                      NaN
# 662                       NaN                      NaN
#
#      certifications_mysql_1  certifications_seo_2  \
# 0                       NaN                   NaN
# 1                       NaN                   NaN
# 2                       NaN                   NaN
# 3                       NaN                   NaN
# 4                       NaN                   NaN
# ..                      ...                   ...
# 658                     NaN                   NaN
# 659                     NaN                   NaN
# 660                     NaN                   NaN
# 661                     NaN                   NaN
# 662                     NaN                   NaN
#
#     certifications_general_orientation_exam_1  certifications_uk_english_1  \
# 0                                         NaN                          NaN
# 1                                         NaN                          NaN
# 2                                         NaN                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
# ..                                        ...                          ...
# 658                                       NaN                          NaN
# 659                                       NaN                          NaN
# 660                                       NaN                          NaN
# 661                                       NaN                          NaN
# 662                                       NaN                          NaN
#
#      certifications_seo_1  certifications_academic_writing_2
# 0                     NaN                                NaN
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                NaN
# ..                    ...                                ...
# 658                   NaN                                NaN
# 659                   NaN                                NaN
# 660                   NaN                                NaN
# 661                   NaN                                NaN
# 662                   NaN                                NaN
#
# [663 rows x 49 columns]

# %%
df.certifications_foundation_vworker_member.unique()
# Out:
# array([nan, True], dtype=object)

# %%
df.certifications_us_english_1.unique()
# Out:
# array(['100%', nan, '95%', '93%', '82%', '92%', '85%', '90%', '80%',
#        '98%', '78%', '97%', '75%', '87%', '77%'], dtype=object)

# %% [markdown]
# #### b. Noting down to-do's
# - ~Get first name~
# - ~Drop tagline and user_description~
# - ~Drop duplicates and missing data~
# - ~Convert join date to more workable version~
# - ~Remove '%' from certification columns and reformat as int or float. Maybe also rename columns to `pct_certifications.....`~
# - ~Fill badge_plus_membership NA with False~
# - ~Maybe? : Remove 'United States' from location (since everything is in the US)~

# %% [markdown]
# ### 4. Define data cleaning function

# %%
def data_cleaner(df):

    # 1. Drop columns that a) have too much missing data or b) are irrelevant
    df_clean = df.drop(['tagline', 'user_description', 'repeat_hire_rate'], axis = 1)

    # 2. Drop duplicates
    if sum(df_clean.duplicated()) > 0:
        df_clean = df_clean.drop_duplicates()
    
    # 3. Drop rows with missing data for hourly_rate column
    df_clean = df_clean.dropna(subset=['hourly_rate'])

    # 4. Convert join date into time on freelancer (baseline: freelancer foundation date)
    join_date_since_est = pd.to_datetime(df_clean.join_date) - dt.datetime(2009,1,1)
    df_clean['join_date_since_est'] = [t_delta.days for t_delta in join_date_since_est]
    df_clean = df_clean.drop(['join_date'], axis = 1)

    # 5. If all hourly rates are given in dollars, remove dollar sign and convert to float
    if (len(df_clean['hourly_rate']) == sum(df_clean['hourly_rate'].str.count('$'))):
        df_clean['hourly_rate'] = df_clean['hourly_rate'].str.replace('$', '', regex = True).astype('float')
    
    # 6. Remove last name initial
    df_clean['name'] = df_clean['name'].str.replace('\s\w.', '', regex = True)

    # 7. Remove '%' from certification columns, reformat as float, and rename columns with 'pct_'
    certColumns = [col for col in df.columns if 'certifications' in col]
    for col in certColumns:
        try:
            df_clean[col] = df_clean[col].replace('%', '', regex = True).astype('float')
        except:
            try:
                print(f"error encountered in {col}.")
                df_clean[col] = df_clean[col].replace('True', np.nan)
                df_clean[col] = df_clean[col].replace('%', '', regex = True).astype('float')
                print(f"replacing 'True' with NaN. If no further error for column, issue resolved\n")
            except:
                print(f"error unresolved in {col}. proceeding without resolution\n")

    df_clean.columns = np.where(df_clean.columns.isin(certColumns), 'pct_' + df_clean.columns, df_clean.columns)

    # 8. Fill badge_plus_membership with False
    df_clean['badge_plus_membership'] =  df_clean['badge_plus_membership'].fillna('False')

    # 9. Remove 'United States' from location
    df_clean['location'] = df_clean['location'].str.split(',').str[0]    

    return df_clean

# %% [markdown]
# ### 5. Run data cleaner on data files

# %%
#Load the data files into pandas dataframes
files = [pd.read_csv(file) for file in file_paths]
files[0].head()
# Out:
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:2: DtypeWarning: Columns (87,143,218,247,248,249,250,354,408,430,432,433,434,471,472,526,527,675,695,716,722,726,727,728,736,839,847,848,849,850,869,970,974,1133,1158,1213,1214,1245,1269,1270,1305,1306,1307,1308,1309,1355,1378,1379,1380,1381,1384,1453,1457,1460,1513,1576,1592,1596,1597,1599,1609,1610,1628,1637,1648,1678,1736,1739,1746,1747,1760,1761,1762,1763,1764,1781,1784,1788,1813,1841,1844,1860,1861,1886,1887,1900,1908,1911,1925,1949,1956,1960,1970,1975,1976,1987,1992,1993,2060,2071,2080,2081,2084,2086,2103,2104) have mixed types.Specify dtype option on import or set low_memory=False.
#
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:2: DtypeWarning: Columns (167,169,330,499,500,521,538,594,596,597,601,613,637,667,672,673,674,733,784,807,834,835,841,873,874,937,972,973,1011,1012,1030,1064,1138,1174,1175,1214,1230,1245,1327,1328,1342,1346,1368,1392,1421,1428,1429,1453,1526,1564,1565,1566,1581,1601,1602,1603,1682,1683) have mixed types.Specify dtype option on import or set low_memory=False.
#   search_query         name                                   profile_link  \
# 0   copywriter     Marty P.            https://www.freelancer.com/u/mpekar
# 1   copywriter       Cat A.           https://www.freelancer.com/u/Cadduci
# 2   copywriter  Jonathan G.              https://www.freelancer.com/u/JG24
# 3   copywriter   Melanie B.     https://www.freelancer.com/u/Melwritesindy
# 4   copywriter  Brittney G.  https://www.freelancer.com/u/satisfiedsoulcre
#
#                                              tagline  \
# 0            Very experienced advertising copywriter
# 1     Marketing, Business and Administrative Support
# 2  Copy Editor, Copywriter, and Marketing Specialist
# 3                   Creative Writer, Copywriter, Mom
# 4                 Copywriter & Brand Content Creator
#
#                                     user_description  \
# 0  I'm a semi-retired advertising copywriter with...
# 1  My name is Cat and I am a Marketing and Commun...
# 2  Wordsmith, editing extraordinaire, and dedicat...
# 3  I studied Creative Writing and English Educati...
# 4  I am your secret weapon to bettering your bran...
#
#                       location          join_date hourly_rate  pay_grade  \
# 0     Greenwich, United States      July 18, 2011         $20        3.6
# 1       Hatboro, United States    August 28, 2021         $15        0.0
# 2       Warwick, United States   January 26, 2016         $20        0.0
# 3  Indianapolis, United States  December 14, 2021         $50        0.0
# 4       Memphis, United States     April 12, 2021         $25        0.0
#
#    avg_rating  ...  skill_electric_repair  skill_handyman  \
# 0         5.0  ...                    NaN             NaN
# 1         0.0  ...                    NaN             NaN
# 2         0.0  ...                    NaN             NaN
# 3         0.0  ...                    NaN             NaN
# 4         0.0  ...                    NaN             NaN
#
#    skill_order_processing  skill_analytics  skill_comics  \
# 0                     NaN              NaN           NaN
# 1                     NaN              NaN           NaN
# 2                     NaN              NaN           NaN
# 3                     NaN              NaN           NaN
# 4                     NaN              NaN           NaN
#
#    skill_public_speaking skill_political_science  skill_activecampaign  \
# 0                    NaN                     NaN                   NaN
# 1                    NaN                     NaN                   NaN
# 2                    NaN                     NaN                   NaN
# 3                    NaN                     NaN                   NaN
# 4                    NaN                     NaN                   NaN
#
#    skill_automotive_engineering  skill_influencer_marketing
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
# [5 rows x 735 columns]

# %% [markdown]
# #### a. Test Run

# %%
ddf = data_cleaner(files[0])
ddf
# Out:
#     search_query       name                                   profile_link  \
# 0     copywriter      Marty            https://www.freelancer.com/u/mpekar
# 1     copywriter        Cat           https://www.freelancer.com/u/Cadduci
# 2     copywriter   Jonathan              https://www.freelancer.com/u/JG24
# 3     copywriter    Melanie     https://www.freelancer.com/u/Melwritesindy
# 4     copywriter   Brittney  https://www.freelancer.com/u/satisfiedsoulcre
# ..           ...        ...                                            ...
# 658   copywriter   Theodore       https://www.freelancer.com/u/greenequail
# 659   copywriter  Luminacht         https://www.freelancer.com/u/Luminacht
# 660   copywriter       Emma    https://www.freelancer.com/u/emmadenning132
# 661   copywriter   Jonathan        https://www.freelancer.com/u/tcoffin014
# 662   copywriter    Niccina    https://www.freelancer.com/u/NicciAKilcoyne
#
#            location  hourly_rate  pay_grade  avg_rating  num_reviews  \
# 0         Greenwich         20.0        3.6         5.0            4
# 1           Hatboro         15.0        0.0         0.0            0
# 2           Warwick         20.0        0.0         0.0            0
# 3      Indianapolis         50.0        0.0         0.0            0
# 4           Memphis         25.0        0.0         0.0            0
# ..              ...          ...        ...         ...          ...
# 658      Scottsdale         20.0        4.7         4.9            8
# 659       Kissimmee         12.0        0.0         0.0            0
# 660       Bryn Mawr         11.0        0.0         0.0            0
# 661  Denham Springs        150.0        0.0         0.0            0
# 662      Wilmington         60.0        1.3         5.0            2
#
#      num_recommendations  pct_jobs_completed  ...  skill_handyman  \
# 0                      0               100.0  ...             NaN
# 1                      0                 NaN  ...             NaN
# 2                      0                 NaN  ...             NaN
# 3                      0                 NaN  ...             NaN
# 4                      0                 NaN  ...             NaN
# ..                   ...                 ...  ...             ...
# 658                    0               100.0  ...             NaN
# 659                    0                 NaN  ...             NaN
# 660                    0                 NaN  ...             NaN
# 661                    0                 NaN  ...             NaN
# 662                    0               100.0  ...             NaN
#
#      skill_order_processing  skill_analytics  skill_comics  \
# 0                       NaN              NaN           NaN
# 1                       NaN              NaN           NaN
# 2                       NaN              NaN           NaN
# 3                       NaN              NaN           NaN
# 4                       NaN              NaN           NaN
# ..                      ...              ...           ...
# 658                     NaN              NaN           0.0
# 659                     NaN              NaN           NaN
# 660                     NaN              NaN           NaN
# 661                     NaN              NaN           NaN
# 662                     NaN              NaN           NaN
#
#      skill_public_speaking  skill_political_science  skill_activecampaign  \
# 0                      NaN                      NaN                   NaN
# 1                      NaN                      NaN                   NaN
# 2                      NaN                      NaN                   NaN
# 3                      NaN                      NaN                   NaN
# 4                      NaN                      NaN                   NaN
# ..                     ...                      ...                   ...
# 658                    0.0                      0.0                   NaN
# 659                    NaN                      NaN                   NaN
# 660                    NaN                      NaN                   NaN
# 661                    NaN                      NaN                   0.0
# 662                    NaN                      NaN                   NaN
#
#      skill_automotive_engineering  skill_influencer_marketing  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ..                            ...                         ...
# 658                           NaN                         NaN
# 659                           NaN                         NaN
# 660                           NaN                         NaN
# 661                           0.0                         0.0
# 662                           NaN                         NaN
#
#      join_date_since_est
# 0                    928
# 1                   4622
# 2                   2581
# 3                   4730
# 4                   4484
# ..                   ...
# 658                 4235
# 659                 4295
# 660                 4331
# 661                 4757
# 662                 3601
#
# [663 rows x 732 columns]

# %% [markdown]
# #### b. Full cleaning run

# %%
cleaned_dataframes = {}

#Iterate through all the data files
for idx in range(len(file_paths)):

    #Clean the data for the particular occupation
    cleaned_df = data_cleaner(files[idx])

    #Get the occupation name
    df_name = file_paths[idx][12:-4]
    print(df_name)

    #Display cleaned data
    display(cleaned_df.head())

    #Store in dictionary for retrieval
    cleaned_dataframes[df_name] = cleaned_df

    #Export to CSV
    cleaned_df.to_csv('../data/interim/'+df_name+'-cleaned.csv',index=False)
# Out:
# copywriter
#   search_query      name                                   profile_link  \
# 0   copywriter     Marty            https://www.freelancer.com/u/mpekar
# 1   copywriter       Cat           https://www.freelancer.com/u/Cadduci
# 2   copywriter  Jonathan              https://www.freelancer.com/u/JG24
# 3   copywriter   Melanie     https://www.freelancer.com/u/Melwritesindy
# 4   copywriter  Brittney  https://www.freelancer.com/u/satisfiedsoulcre
#
#        location  hourly_rate  pay_grade  avg_rating  num_reviews  \
# 0     Greenwich         20.0        3.6         5.0            4
# 1       Hatboro         15.0        0.0         0.0            0
# 2       Warwick         20.0        0.0         0.0            0
# 3  Indianapolis         50.0        0.0         0.0            0
# 4       Memphis         25.0        0.0         0.0            0
#
#    num_recommendations  pct_jobs_completed  ...  skill_handyman  \
# 0                    0               100.0  ...             NaN
# 1                    0                 NaN  ...             NaN
# 2                    0                 NaN  ...             NaN
# 3                    0                 NaN  ...             NaN
# 4                    0                 NaN  ...             NaN
#
#    skill_order_processing  skill_analytics  skill_comics  \
# 0                     NaN              NaN           NaN
# 1                     NaN              NaN           NaN
# 2                     NaN              NaN           NaN
# 3                     NaN              NaN           NaN
# 4                     NaN              NaN           NaN
#
#    skill_public_speaking  skill_political_science  skill_activecampaign  \
# 0                    NaN                      NaN                   NaN
# 1                    NaN                      NaN                   NaN
# 2                    NaN                      NaN                   NaN
# 3                    NaN                      NaN                   NaN
# 4                    NaN                      NaN                   NaN
#
#    skill_automotive_engineering  skill_influencer_marketing  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#    join_date_since_est
# 0                  928
# 1                 4622
# 2                 2581
# 3                 4730
# 4                 4484
#
# [5 rows x 732 columns]
# error encountered in certifications_us_english_1.
# replacing 'True' with NaN. If no further error for column, issue resolved
#
# error encountered in certifications_employer_orientation_exam_1.
# replacing 'True' with NaN. If no further error for column, issue resolved
#
# software_engineer
#         search_query    name                                 profile_link  \
# 0  software engineer   Frank  https://www.freelancer.com/u/frankvigilante
# 1  software engineer     Tim       https://www.freelancer.com/u/Nightbane
# 2  software engineer  Silvio     https://www.freelancer.com/u/Marchoshd77
# 3  software engineer  Albert      https://www.freelancer.com/u/AlbertHtet
# 4  software engineer    Maaz    https://www.freelancer.com/u/codingcounty
#
#        location  hourly_rate  pay_grade  avg_rating  num_reviews  \
# 0       Chicago         99.0        3.0         0.0            0
# 1    Burlington         25.0        1.6         5.0            2
# 2      Chuluota         50.0        0.0         0.0            0
# 3      New York          8.0        0.0         0.0            0
# 4  West Windsor         10.0        1.7         5.0            1
#
#    num_recommendations  pct_jobs_completed  ...  \
# 0                    0               100.0  ...
# 1                    0               100.0  ...
# 2                    0                 NaN  ...
# 3                    0                 NaN  ...
# 4                    0               100.0  ...
#
#    pct_certifications_google_webmaster_central_1  skill_modx  skill_cubecart  \
# 0                                            NaN         NaN             NaN
# 1                                            NaN         NaN             NaN
# 2                                            NaN         NaN             NaN
# 3                                            NaN         NaN             NaN
# 4                                            NaN         NaN             NaN
#
#    skill_phaser  skill_drilling_engineering  skill_designbuilder  \
# 0           NaN                         NaN                  NaN
# 1           NaN                         NaN                  NaN
# 2           NaN                         NaN                  NaN
# 3           NaN                         NaN                  NaN
# 4           NaN                         NaN                  NaN
#
#    skill_casperjs  skill_apple_ibooks_author  skill_flower_delivery  \
# 0             NaN                        NaN                    NaN
# 1             NaN                        NaN                    NaN
# 2             NaN                        NaN                    NaN
# 3             NaN                        NaN                    NaN
# 4             NaN                        NaN                    NaN
#
#    join_date_since_est
# 0                 2345
# 1                 3211
# 2                 4585
# 3                 2291
# 4                 4006
#
# [5 rows x 2110 columns]
# error encountered in certifications_freelancer_orientation_1.
# replacing 'True' with NaN. If no further error for column, issue resolved
#
# error encountered in certifications_employer_orientation_exam_1.
# replacing 'True' with NaN. If no further error for column, issue resolved
#
# designer
#   search_query     name                                 profile_link  \
# 0     designer    Milen  https://www.freelancer.com/u/MsCaddServices
# 1     designer   Jeremy         https://www.freelancer.com/u/Conescu
# 2     designer  Nichole       https://www.freelancer.com/u/NicholeMW
# 3     designer   Robert     https://www.freelancer.com/u/rhoenig1277
# 4     designer     Shea      https://www.freelancer.com/u/blaqsupply
#
#        location  hourly_rate  pay_grade  avg_rating  num_reviews  \
# 0       Edmonds         45.0        0.0         0.0            0
# 1        Orinda         90.0        0.0         0.0            0
# 2         Holly         25.0        4.0         5.0            2
# 3        Beloit         75.0        0.0         0.0            0
# 4  Cockeysville         25.0        0.0         0.0            0
#
#    num_recommendations  pct_jobs_completed  ...  skill_process_validation  \
# 0                    0                 NaN  ...                       NaN
# 1                    0                 NaN  ...                       NaN
# 2                    0               100.0  ...                       NaN
# 3                    0                 NaN  ...                       NaN
# 4                    0                 NaN  ...                       NaN
#
#    skill_supply_chain  skill_technical_recruiter  skill_sourcing  \
# 0                 NaN                        NaN             NaN
# 1                 NaN                        NaN             NaN
# 2                 NaN                        NaN             NaN
# 3                 NaN                        NaN             NaN
# 4                 NaN                        NaN             NaN
#
#    skill_investment_management  skill_chemistry_tutoring  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
#
#    skill_career_consulting  skill_development_assessment  skill_learndash  \
# 0                      NaN                           NaN              NaN
# 1                      NaN                           NaN              NaN
# 2                      NaN                           NaN              NaN
# 3                      NaN                           NaN              NaN
# 4                      NaN                           NaN              NaN
#
#    join_date_since_est
# 0                 4306
# 1                 4769
# 2                 3673
# 3                  481
# 4                 2514
#
# [5 rows x 1706 columns]
# accountant
#   search_query     name                                profile_link  \
# 0   accountant    Nancy     https://www.freelancer.com/u/Nmatilszki
# 1   accountant   Robert  https://www.freelancer.com/u/Rdellaventura
# 2   accountant  Hafizam    https://www.freelancer.com/u/azamanwar89
# 3   accountant    Wasif   https://www.freelancer.com/u/usamaameer26
# 4   accountant  Patrick       https://www.freelancer.com/u/keter217
#
#         location  hourly_rate  pay_grade  avg_rating  num_reviews  \
# 0      Davenport         25.0        0.0         0.0            0
# 1       Cranston         25.0        0.0         0.0            0
# 2  Fresh Meadows         45.0        2.6         4.8            3
# 3     Gujranwala         10.0        0.0         0.0            0
# 4     Birmingham        300.0        0.0         0.0            0
#
#    num_recommendations  pct_jobs_completed  ...  \
# 0                    0                 NaN  ...
# 1                    0                 NaN  ...
# 2                    0               100.0  ...
# 3                    0                 NaN  ...
# 4                    0                 NaN  ...
#
#    pct_certifications_employer_orientation_exam_1  skill_bulk_marketing  \
# 0                                             NaN                   NaN
# 1                                             NaN                   NaN
# 2                                             NaN                   NaN
# 3                                             NaN                   NaN
# 4                                             NaN                   NaN
#
#    skill_leads  skill_music  skill_youtube_video_editing  \
# 0          NaN          NaN                          NaN
# 1          NaN          NaN                          NaN
# 2          NaN          NaN                          NaN
# 3          NaN          NaN                          NaN
# 4          NaN          NaN                          NaN
#
#    skill_psychological_assessment  skill_search_engine_marketing  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    skill_legal_assistance  skill_civil_engineering  join_date_since_est
# 0                     NaN                      NaN                 4613
# 1                     NaN                      NaN                 4717
# 2                     NaN                      NaN                 3748
# 3                     NaN                      NaN                 4099
# 4                     NaN                      NaN                 4778
#
# [5 rows x 675 columns]

# %%
files[2].certifications_freelancer_orientation_1.unique()
# Out:
# array([nan, '90%', 'True', '80%', '75%', '85%', '100%', '95%', '70%'],
#       dtype=object)

# %%
cleaned_dataframes['software_engineer'].pct_certifications_us_english_1.unique()
# Out:
# array([ 85.,  90.,  nan,  95.,  92.,  78.,  77.,  82.,  83.,  87., 100.,
#         98.,  93.,  80.,  97.,  75.,  88.,  94.])

# %% [markdown]
# ### 6. Merge cleaned data

# %% [markdown]
# #### a. Get the paths to all the cleaned CSV files

# %%
cleaned_files_paths = [file for file in glob('../data/interim/*-cleaned.csv')]
cleaned_files_paths
# Out:
# ['../data/interim/designer-cleaned.csv',
#  '../data/interim/accountant-cleaned.csv',
#  '../data/interim/copywriter-cleaned.csv',
#  '../data/interim/software_engineer-cleaned.csv']

# %% [markdown]
# #### b. Read the cleaned files into CSVs and store in list

# %%
#Read the cleaned files into a CSV
cleaned_dfs = [pd.read_csv(path,low_memory=False) for path in cleaned_files_paths ]

# %% [markdown]
# #### c. Merge into one CSV

# %%
merged_df = pd.concat(cleaned_dfs,ignore_index=True)
print(merged_df.shape)
merged_df.head()
# Out:
# (10094, 2265)
#   search_query     name                                 profile_link  \
# 0     designer    Milen  https://www.freelancer.com/u/MsCaddServices
# 1     designer   Jeremy         https://www.freelancer.com/u/Conescu
# 2     designer  Nichole       https://www.freelancer.com/u/NicholeMW
# 3     designer   Robert     https://www.freelancer.com/u/rhoenig1277
# 4     designer     Shea      https://www.freelancer.com/u/blaqsupply
#
#        location  hourly_rate  pay_grade  avg_rating  num_reviews  \
# 0       Edmonds         45.0        0.0         0.0            0
# 1        Orinda         90.0        0.0         0.0            0
# 2         Holly         25.0        4.0         5.0            2
# 3        Beloit         75.0        0.0         0.0            0
# 4  Cockeysville         25.0        0.0         0.0            0
#
#    num_recommendations  pct_jobs_completed  ...  \
# 0                    0                 NaN  ...
# 1                    0                 NaN  ...
# 2                    0               100.0  ...
# 3                    0                 NaN  ...
# 4                    0                 NaN  ...
#
#    pct_certifications_requirements_engineering_1  skill_furniture_removalist  \
# 0                                            NaN                         NaN
# 1                                            NaN                         NaN
# 2                                            NaN                         NaN
# 3                                            NaN                         NaN
# 4                                            NaN                         NaN
#
#    skill_workday_security  skill_oracle_ebs_tech_integration  \
# 0                     NaN                                NaN
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                NaN
#
#    pct_certifications_google_webmaster_central_1  skill_modx  skill_cubecart  \
# 0                                            NaN         NaN             NaN
# 1                                            NaN         NaN             NaN
# 2                                            NaN         NaN             NaN
# 3                                            NaN         NaN             NaN
# 4                                            NaN         NaN             NaN
#
#    skill_phaser  skill_drilling_engineering  skill_casperjs
# 0           NaN                         NaN             NaN
# 1           NaN                         NaN             NaN
# 2           NaN                         NaN             NaN
# 3           NaN                         NaN             NaN
# 4           NaN                         NaN             NaN
#
# [5 rows x 2265 columns]

# %% [markdown]
# #### d. Write merged_df into CSV

# %%
merged_df.to_csv('../data/interim/cleaned-merge.csv', index=False)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=acc27b92-84be-4130-8026-204943f38189' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
